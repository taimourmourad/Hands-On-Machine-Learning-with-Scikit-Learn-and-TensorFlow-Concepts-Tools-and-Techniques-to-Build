# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
K = keras.backend

# %%
# First we need a custom layer to sample the Codings given mean and std

class Sampling(keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return K.random_normal(tf.shape(log_var)) * K.exp(log_var / 2) + mean#exp is equivalent to std

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
tf.random.set_seed(42)
np.random.seed(42)

codings_size = 10

inputs = keras.layers.Input(shape=[28, 28])
z = keras.layers.Flatten()(inputs)
z = keras.layers.Dense(150, activation="selu")(z)
z = keras.layers.Dense(100, activation="selu")(z)
codings_mean = keras.layers.Dense(codings_size)(z)
codings_log_var = keras.layers.Dense(codings_size)(z)
codings = Sampling()([codings_mean, codings_log_var])
variational_encoder = keras.models.Model(
    inputs=[inputs], outputs=[codings_mean, codings_log_var, codings])

decoder_inputs = keras.layers.Input(shape=[codings_size])
x = keras.layers.Dense(100, activation="selu")(decoder_inputs)
x = keras.layers.Dense(150, activation="selu")(x)
x = keras.layers.Dense(28 * 28, activation="sigmoid")(x)
outputs = keras.layers.Reshape([28, 28])(x)
variational_decoder = keras.models.Model(inputs=[decoder_inputs], outputs=[outputs])

_, _, codings = variational_encoder(inputs)
reconstructions = variational_decoder(codings)
variational_ae = keras.models.Model(inputs=[inputs], outputs=[reconstructions])

latent_loss = -0.5 * K.sum(
    1 + codings_log_var - K.exp(codings_log_var) - K.square(codings_mean),
    axis=-1)
variational_ae.add_loss(K.mean(latent_loss) / 784.)
variational_ae.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=[rounded_accuracy])
history = variational_ae.fit(X_train, X_train, epochs=25, batch_size=128,
                             validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/25
# 430/430 [==============================] - 6s 12ms/step - loss: 0.4438 - rounded_accuracy: 0.8154 - val_loss: 0.3508 - val_rounded_accuracy: 0.8925
# Epoch 2/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3462 - rounded_accuracy: 0.8952 - val_loss: 0.3366 - val_rounded_accuracy: 0.9028
# Epoch 3/25
# 430/430 [==============================] - 5s 11ms/step - loss: 0.3341 - rounded_accuracy: 0.9038 - val_loss: 0.3309 - val_rounded_accuracy: 0.9088
# Epoch 4/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3290 - rounded_accuracy: 0.9082 - val_loss: 0.3271 - val_rounded_accuracy: 0.9110
# Epoch 5/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3255 - rounded_accuracy: 0.9113 - val_loss: 0.3249 - val_rounded_accuracy: 0.9151
# Epoch 6/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3242 - rounded_accuracy: 0.9131 - val_loss: 0.3253 - val_rounded_accuracy: 0.9096
# Epoch 7/25
# 430/430 [==============================] - 5s 11ms/step - loss: 0.3218 - rounded_accuracy: 0.9145 - val_loss: 0.3226 - val_rounded_accuracy: 0.9134
# Epoch 8/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3195 - rounded_accuracy: 0.9162 - val_loss: 0.3212 - val_rounded_accuracy: 0.9157
# Epoch 9/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3196 - rounded_accuracy: 0.9165 - val_loss: 0.3219 - val_rounded_accuracy: 0.9125
# Epoch 10/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3179 - rounded_accuracy: 0.9177 - val_loss: 0.3181 - val_rounded_accuracy: 0.9196
# Epoch 11/25
# 430/430 [==============================] - 5s 11ms/step - loss: 0.3178 - rounded_accuracy: 0.9175 - val_loss: 0.3197 - val_rounded_accuracy: 0.9177
# Epoch 12/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3165 - rounded_accuracy: 0.9188 - val_loss: 0.3186 - val_rounded_accuracy: 0.9201
# Epoch 13/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3158 - rounded_accuracy: 0.9191 - val_loss: 0.3179 - val_rounded_accuracy: 0.9205
# Epoch 14/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3149 - rounded_accuracy: 0.9200 - val_loss: 0.3173 - val_rounded_accuracy: 0.9172
# Epoch 15/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3146 - rounded_accuracy: 0.9198 - val_loss: 0.3203 - val_rounded_accuracy: 0.9174
# Epoch 16/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3151 - rounded_accuracy: 0.9198 - val_loss: 0.3182 - val_rounded_accuracy: 0.9194
# Epoch 17/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3145 - rounded_accuracy: 0.9204 - val_loss: 0.3164 - val_rounded_accuracy: 0.9213
# Epoch 18/25
# 430/430 [==============================] - 5s 11ms/step - loss: 0.3136 - rounded_accuracy: 0.9207 - val_loss: 0.3152 - val_rounded_accuracy: 0.9225
# Epoch 19/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3133 - rounded_accuracy: 0.9215 - val_loss: 0.3156 - val_rounded_accuracy: 0.9222
# Epoch 20/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3125 - rounded_accuracy: 0.9213 - val_loss: 0.3145 - val_rounded_accuracy: 0.9221
# Epoch 21/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3132 - rounded_accuracy: 0.9215 - val_loss: 0.3165 - val_rounded_accuracy: 0.9201
# Epoch 22/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3125 - rounded_accuracy: 0.9216 - val_loss: 0.3128 - val_rounded_accuracy: 0.9227
# Epoch 23/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3120 - rounded_accuracy: 0.9214 - val_loss: 0.3157 - val_rounded_accuracy: 0.9223
# Epoch 24/25
# 430/430 [==============================] - 4s 10ms/step - loss: 0.3125 - rounded_accuracy: 0.9221 - val_loss: 0.3146 - val_rounded_accuracy: 0.9220
# Epoch 25/25
# 430/430 [==============================] - 5s 11ms/step - loss: 0.3113 - rounded_accuracy: 0.9219 - val_loss: 0.3130 - val_rounded_accuracy: 0.9225
