# %%
#2. the following code builds a stacked AutoEncoder for Fashion MNIST

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
tf.random.set_seed(42)
np.random.seed(42)

stacked_encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(100, activation="selu"),
    keras.layers.Dense(30, activation="selu"),
])
stacked_decoder = keras.models.Sequential([
    keras.layers.Dense(100, activation="selu", input_shape=[30]),
    keras.layers.Dense(28 * 28, activation="sigmoid"),
    keras.layers.Reshape([28, 28])
])
stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])
stacked_ae.compile(loss="binary_crossentropy",
                   optimizer=keras.optimizers.SGD(lr=1.5), metrics=[rounded_accuracy])
history = stacked_ae.fit(X_train, X_train, epochs=30,
                         validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3814 - rounded_accuracy: 0.8487 - val_loss: 0.3169 - val_rounded_accuracy: 0.8998
# Epoch 2/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3083 - rounded_accuracy: 0.9126 - val_loss: 0.3021 - val_rounded_accuracy: 0.9200
# Epoch 3/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2997 - rounded_accuracy: 0.9204 - val_loss: 0.2982 - val_rounded_accuracy: 0.9206
# Epoch 4/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2959 - rounded_accuracy: 0.9240 - val_loss: 0.2937 - val_rounded_accuracy: 0.9285
# Epoch 5/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2928 - rounded_accuracy: 0.9269 - val_loss: 0.2919 - val_rounded_accuracy: 0.9284
# Epoch 6/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2920 - rounded_accuracy: 0.9283 - val_loss: 0.2916 - val_rounded_accuracy: 0.9305
# Epoch 7/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2899 - rounded_accuracy: 0.9297 - val_loss: 0.2907 - val_rounded_accuracy: 0.9279
# Epoch 8/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2875 - rounded_accuracy: 0.9314 - val_loss: 0.2946 - val_rounded_accuracy: 0.9296
# Epoch 9/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2878 - rounded_accuracy: 0.9316 - val_loss: 0.2905 - val_rounded_accuracy: 0.9260
# Epoch 10/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2860 - rounded_accuracy: 0.9329 - val_loss: 0.2881 - val_rounded_accuracy: 0.9304
# Epoch 11/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2859 - rounded_accuracy: 0.9330 - val_loss: 0.2864 - val_rounded_accuracy: 0.9348
# Epoch 12/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2845 - rounded_accuracy: 0.9343 - val_loss: 0.2856 - val_rounded_accuracy: 0.9356
# Epoch 13/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2838 - rounded_accuracy: 0.9343 - val_loss: 0.2847 - val_rounded_accuracy: 0.9355
# Epoch 14/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2830 - rounded_accuracy: 0.9353 - val_loss: 0.2844 - val_rounded_accuracy: 0.9365
# Epoch 15/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2827 - rounded_accuracy: 0.9354 - val_loss: 0.2841 - val_rounded_accuracy: 0.9352
# Epoch 16/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2831 - rounded_accuracy: 0.9356 - val_loss: 0.2845 - val_rounded_accuracy: 0.9355
# Epoch 17/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2827 - rounded_accuracy: 0.9358 - val_loss: 0.2835 - val_rounded_accuracy: 0.9363
# Epoch 18/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2815 - rounded_accuracy: 0.9366 - val_loss: 0.2831 - val_rounded_accuracy: 0.9365
# Epoch 19/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2813 - rounded_accuracy: 0.9371 - val_loss: 0.2827 - val_rounded_accuracy: 0.9374
# Epoch 20/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2806 - rounded_accuracy: 0.9371 - val_loss: 0.2842 - val_rounded_accuracy: 0.9366
# Epoch 21/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2812 - rounded_accuracy: 0.9371 - val_loss: 0.2833 - val_rounded_accuracy: 0.9351
# Epoch 22/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2805 - rounded_accuracy: 0.9373 - val_loss: 0.2825 - val_rounded_accuracy: 0.9374
# Epoch 23/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2800 - rounded_accuracy: 0.9371 - val_loss: 0.2833 - val_rounded_accuracy: 0.9336
# Epoch 24/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2805 - rounded_accuracy: 0.9376 - val_loss: 0.2820 - val_rounded_accuracy: 0.9377
# Epoch 25/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2794 - rounded_accuracy: 0.9376 - val_loss: 0.2817 - val_rounded_accuracy: 0.9377
# Epoch 26/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2796 - rounded_accuracy: 0.9379 - val_loss: 0.2825 - val_rounded_accuracy: 0.9370
# Epoch 27/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2801 - rounded_accuracy: 0.9377 - val_loss: 0.2811 - val_rounded_accuracy: 0.9376
# Epoch 28/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2791 - rounded_accuracy: 0.9384 - val_loss: 0.2810 - val_rounded_accuracy: 0.9385
# Epoch 29/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2796 - rounded_accuracy: 0.9381 - val_loss: 0.2819 - val_rounded_accuracy: 0.9355
# Epoch 30/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2794 - rounded_accuracy: 0.9381 - val_loss: 0.2805 - val_rounded_accuracy: 0.9383

# %% [markdown]
# **let's plot a few images from teh validation set, as well as their reconstructions**

# %%
def plot_image(image):
    plt.imshow(image, cmap='binary')
    plt.axis('off')
    
def show_reconstructions(model, n_images=5):
    reconstructions = model.predict(X_valid[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1+image_index)
        plot_image(X_valid[image_index])
        plt.subplot(2, n_images, 1+n_images + image_index)
        plot_image(reconstructions[image_index])
        
show_reconstructions(stacked_ae)

# %%
from sklearn.manifold import TSNE

# %%
X_valid_compressed = stacked_encoder.predict(X_valid)
tsne = TSNE()
X_valid_2D = tsne.fit_transform(X_valid_compressed)

# %%
plt.figure(figsize=(12, 9))
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap='tab10')
